# %%
# %cd leffa
# Out:
# /home/kim/Leffa/leffa
# /home/kim/anaconda3/envs/Leffa/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
#3rdparty   app.py      in_img				 leffa_utils
#LICENSE    ckpts       leffa				 preprocess
#README.md  densepose   leffa_test.ipynb			 requirements.txt
#SCHP	   detectron2  leffa_test.ipynb:Zone.Identifier  vton_script.py

# %%
from vton_script import LeffaVirtualTryOn
from IPython.display import display
import os

# LeffaVirtualTryOn 초기화
vton = LeffaVirtualTryOn(ckpt_dir="./ckpts")

# 출력 디렉터리 확인 및 생성
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 가상 착용 실행
agnostic_image,skin_image = vton.skin_test(
    src_image_path="in_img/uz.png",
    ref_image_path="in_img/s0047.jpg",
    control_type="virtual_tryon",
    vt_model_type="viton_hd",  # "viton_hd", "dress_code"
    vt_garment_type="short_sleeve",  # upper_body, dresses, lower_body, short_sleeve, shorts
    step=20,
    cross_attention_kwargs=3,
    vt_repaint=False,
    output_path=f"{output_dir}/virtual_tryon_result2.jpg"
)

display(agnostic_image)

display(skin_image)

# display(limb_mask_img)
# Out:
# /home/kim/anaconda3/envs/Leffa/lib/python3.10/site-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4314.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.39s/it]
# <PIL.Image.Image image mode=RGB size=768x1024>
# <PIL.Image.Image image mode=RGB size=768x1024>

# %%
from vton_script import LeffaVirtualTryOn
from IPython.display import display
import os

# LeffaVirtualTryOn 초기화
vton = LeffaVirtualTryOn(ckpt_dir="./ckpts")

# 출력 디렉터리 확인 및 생성
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

model_path = 'Self-Correction-Human-Parsing/models/lip_jpp_single.pth'
input_image = 'in_img/uz.png'  # 긴팔 착용 이미지

if os.path.exists(input_image):
    vton.make_upper_body_nude(input_image, model_path)
else:
    print(f"Input image not found: {input_image}")
# Out:
# Using /home/kim/.cache/torch_extensions/py310_cu126 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from vton_script import LeffaVirtualTryOn
#       2 from IPython.display import display
#       3 import os
#
# File ~/Leffa/vton_script.py:22
#      19 from PIL import Image
#      20 from torchvision import transforms
# ---> 22 from networks.simple_extractor import JPPNet  # SCHP/LIP 파싱 모델
#      23 from leffa_utils.utils import resize_and_center
#      25 class LeffaVirtualTryOn:
#
# File ~/Leffa/preprocess/humanparsing/networks/__init__.py:2
#       1 from __future__ import absolute_import
# ----> 2 from networks.AugmentCE2P import resnet101
#       4 __factory = {
#       5     'resnet101': resnet101,
#       6 }
#       9 def init_model(name, *args, **kwargs):
#
# ...

# %%
from vton_script import LeffaVirtualTryOn
from IPython.display import display
import os

# LeffaVirtualTryOn 초기화
vton = LeffaVirtualTryOn(ckpt_dir="./ckpts")

# 출력 디렉터리 확인 및 생성
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 가상 착용 실행
agnostic_image,skin_image = vton.skin_test(
    src_image_path="in_img/uz.png",
    ref_image_path="in_img/s0047.jpg",
    control_type="virtual_tryon",
    vt_model_type="viton_hd",  # "viton_hd", "dress_code"
    vt_garment_type="short_sleeve",  # upper_body, dresses, lower_body, short_sleeve, shorts
    step=20,
    cross_attention_kwargs=3,
    vt_repaint=False,
    output_path=f"{output_dir}/virtual_tryon_result2.jpg"
)

display(agnostic_image)

display(skin_image)

# display(limb_mask_img)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from vton_script import LeffaVirtualTryOn
#       2 from IPython.display import display
#       3 import os
#
# File ~/Leffa/vton_script.py:22
#      19 from PIL import Image
#      20 from torchvision import transforms
# ---> 22 from networks.simple_extractor import JPPNet  # SCHP/LIP 파싱 모델
#      23 from leffa_utils.utils import resize_and_center
#      25 class LeffaVirtualTryOn:
#
# File ~/Leffa/preprocess/humanparsing/networks/__init__.py:2
#       1 from __future__ import absolute_import
# ----> 2 from networks.AugmentCE2P import resnet101
#       4 __factory = {
#       5     'resnet101': resnet101,
#       6 }
#       9 def init_model(name, *args, **kwargs):
#
# File ~/Leffa/preprocess/humanparsing/networks/AugmentCE2P.py:22
#      19 from torch.nn import functional as F
# ...

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.7.1+cu126
# 12.6
